# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import matplotlib.lines
from matplotlib.animation import FuncAnimation
import time

# %%
def upd(frame):
    print('abc')
    anim.event_source.stop()
    f = plt.figure()
    anim = FuncAnimation(f, upd, interval=5)
    plt.show()

# %%
for i in range(4):
    print('a')
    time.sleep(15)
# Out:
# a
# a
# a
# a

# %%
for i in range(4):
    print('b')
    time.sleep(15)
# Out:
# b
# b
# b
# b

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="747.7272565207209">

# %%
# Now later you get a new subplot; change the geometry of the existing
n = len(fig.axes)
for i in range(n):
    fig.axes[i].change_geometry(n+1, 1, i+1)

# %%
# Add the new
ax = fig.add_subplot(n+1, 1, n+1)
ax.plot([4,5,6])

# %%
fig.set_size_inches(20,20)

# %%
fig.tight_layout()
