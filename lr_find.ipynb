# %%
# %matplotlib notebook
import longview as lv

# %%
cli_train = lv.WatchClient()
plot = lv.LinePlot()

# %%
train_batch_loss = cli_train.create_stream('batch', 'map(lambda d:(d.tt.scheduler.get_lr(), d.metrics.batch_loss), l)')
plot.show(train_batch_loss, xlabel='LR', ylabel='Loss')
# Out:
# <img src="data:image/png;base64,..." width="888">

# %%
grads = cli_train.create_stream('batch', 'map(lambda d:avg_abs_grads(d.model), l)', throttle=3)
grad_plot = lv.LinePlot()
grad_plot.show(grads, xlabel='Epoch', ylabel='Gradients', redraw_after=0, keep_old=20, dim_old=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
