# %%
# %matplotlib notebook
import longview as lv

# %%
cli = lv.WatchClient()

# %%
cli.show_stream("TestEvent", 'lambda d: math.sqrt(len(d))')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cli.show_stream("TestEvent", 'lambda d: len(d)')
# Out:
# <img src="data:image/png;base64,..." width="640">
